# %% [markdown]
# in **1st** **stage we will **load** and **understand data** and check any **missing value** ,understand columns which is **numerical or categorical** and understand **correlation**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# For better visual settings
sns.set(style="whitegrid", palette="pastel", font_scale=1.1)
df = pd.read_csv('/kaggle/input/housing-prices-dataset/Housing.csv')
df.head(2)
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished

# %%
df.shape
# Out:
# (545, 13)

# %%
df.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
df.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
df.dtypes
# Out:
# price                int64
# area                 int64
# bedrooms             int64
# bathrooms            int64
# stories              int64
# mainroad            object
# guestroom           object
# basement            object
# hotwaterheating     object
# airconditioning     object
# parking              int64
# prefarea            object
# furnishingstatus    object
# dtype: object

# %%
categorical_cols = df.select_dtypes(include=['object'])
numerical_cols = df.select_dtypes(include=['int']).columns.tolist()
categorical_cols.head(2)
# Out:
#   mainroad guestroom basement hotwaterheating airconditioning prefarea  \
# 0      yes        no       no              no             yes      yes
# 1      yes        no       no              no             yes       no
#
#   furnishingstatus
# 0        furnished
# 1        furnished

# %%
numerical_cols
# Out:
# ['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'parking']

# %%
for i in categorical_cols:
    print(f"{df[i].nunique()} : {df[i].unique()[:10]}")
# Out:
# 2 : ['yes' 'no']
# 2 : ['no' 'yes']
# 2 : ['no' 'yes']
# 2 : ['no' 'yes']
# 2 : ['yes' 'no']
# 2 : ['yes' 'no']
# 3 : ['furnished' 'semi-furnished' 'unfurnished']

# %%
# Step 7: Correlation matrix (numerical only)
plt.figure(figsize=(8,6))
sns.heatmap(df[numerical_cols].corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap (Numerical Features)")
plt.show()

# %%
num_cols = ['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'parking']
plt.figure(figsize=(14,8))
for i, col in enumerate(num_cols):
    plt.subplot(2, 3, i+1)
    sns.histplot(df[col], bins=20, kde=True, color='skyblue')
    plt.title(col)
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# we have successfully Loaded and explored the dataset Identified numerical vs categorical columns Checked missing data Viewed distributions and correlations,defined categorical and numerical diffrently

# %% [markdown]
# stage 1 data cleaing and preprocessing,encding data

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df[numerical_cols] = scaler.fit_transform(df[numerical_cols])
df
# Out:
#         price      area  bedrooms  bathrooms   stories mainroad guestroom  \
# 0    4.566365  1.046726  1.403419   1.421812  1.378217      yes        no
# 1    4.004484  1.757010  1.403419   5.405809  2.532024      yes        no
# 2    4.004484  2.218232  0.047278   1.421812  0.224410      yes        no
# 3    3.985755  1.083624  1.403419   1.421812  0.224410      yes        no
# 4    3.554979  1.046726  1.403419  -0.570187  0.224410      yes       yes
# ..        ...       ...       ...        ...       ...      ...       ...
# 540 -1.576868 -0.991879 -1.308863  -0.570187 -0.929397      yes        no
# 541 -1.605149 -1.268613  0.047278  -0.570187 -0.929397       no        no
# 542 -1.614327 -0.705921 -1.308863  -0.570187 -0.929397      yes        no
# 543 -1.614327 -1.033389  0.047278  -0.570187 -0.929397       no        no
# 544 -1.614327 -0.599839  0.047278  -0.570187  0.224410      yes        no
#
#     basement hotwaterheating airconditioning   parking prefarea  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OrdinalEncoder

# %%
le = LabelEncoder()
binary_cols = ['mainroad', 'guestroom', 'basement', 
               'hotwaterheating', 'airconditioning', 'prefarea']
for col in binary_cols:
    df[col] = le.fit_transform(df[col])

# %%
df.head()
# Out:
#       price      area  bedrooms  bathrooms   stories  mainroad  guestroom  \
# 0  4.566365  1.046726  1.403419   1.421812  1.378217         1          0
# 1  4.004484  1.757010  1.403419   5.405809  2.532024         1          0
# 2  4.004484  2.218232  0.047278   1.421812  0.224410         1          0
# 3  3.985755  1.083624  1.403419   1.421812  0.224410         1          0
# 4  3.554979  1.046726  1.403419  -0.570187  0.224410         1          1
#
#    basement  hotwaterheating  airconditioning   parking  prefarea  \
# 0         0                0                1  1.517692         1
# 1         0                0                1  2.679409         0
# 2         1                0                0  1.517692         1
# 3         1                0                1  2.679409         1
# 4         1                0                1  1.517692         0
#
#   furnishingstatus
# 0        furnished
# 1        furnished
# 2   semi-furnished
# 3        furnished
# 4        furnished

# %%
df = pd.get_dummies(df,columns=['furnishingstatus'],drop_first=False)
df.head()
# Out:
#       price      area  bedrooms  bathrooms   stories  mainroad  guestroom  \
# 0  4.566365  1.046726  1.403419   1.421812  1.378217         1          0
# 1  4.004484  1.757010  1.403419   5.405809  2.532024         1          0
# 2  4.004484  2.218232  0.047278   1.421812  0.224410         1          0
# 3  3.985755  1.083624  1.403419   1.421812  0.224410         1          0
# 4  3.554979  1.046726  1.403419  -0.570187  0.224410         1          1
#
#    basement  hotwaterheating  airconditioning   parking  prefarea  \
# 0         0                0                1  1.517692         1
# 1         0                0                1  2.679409         0
# 2         1                0                0  1.517692         1
# 3         1                0                1  2.679409         1
# 4         1                0                1  1.517692         0
#
#    furnishingstatus_furnished  furnishingstatus_semi-furnished  \
# ...

# %%
num_cols = ['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'parking']

plt.figure(figsize=(12, 6))
for i, col in enumerate(num_cols):
    plt.subplot(2, 3, i+1)
    sns.boxplot(y=df[col], color='lightblue')
    plt.title(f"Outliers in {col}")
plt.tight_layout()
plt.show()

# %% [markdown]
# handling outliers

# %%
def cap_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    df[column] = np.where(df[column] < lower, lower, df[column])
    df[column] = np.where(df[column] > upper, upper, df[column])

for col in ['price', 'area']:
    cap_outliers(df, col)

print("✅ Outliers capped successfully!")
# Out:
# ✅ Outliers capped successfully!

# %%
num_cols = ['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'parking']

plt.figure(figsize=(12, 6))
for i, col in enumerate(num_cols):
    plt.subplot(2, 3, i+1)
    sns.boxplot(y=df[col], color='lightblue')
    plt.title(f"Outliers in {col}")
plt.tight_layout()
plt.show()

# %% [markdown]
# stage 2 of eda data vsualization

# %%
num_cols = ['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'parking']

plt.figure(figsize=(14,10))
for i, col in enumerate(num_cols):
    plt.subplot(3, 2, i+1)
    sns.histplot(df[col], kde=True, bins=25, color='skyblue')
    plt.title(f"Distribution of {col}")
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
sns.pairplot(df[num_cols], diag_kind="kde")
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x=df['area'], y=df['price'], color="blue")
plt.title("Area vs Price")
plt.show()

# %%
sns.boxplot(x=df['bedrooms'], y=df['price'], palette="Set2")
plt.title("Price by Bedroom Count")
plt.show()

# %%
df.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus_furnished',
#        'furnishingstatus_semi-furnished', 'furnishingstatus_unfurnished'],
#       dtype='object')

# %%
df['pricepersqfeet'] = df['price']/df['area']

# %%
df['total_rooms'] = df['bedrooms']+df['bathrooms']

# %%
df['area_bathrooms'] = df['area'] * df['bathrooms']

# %%
df['price_log'] = np.log1p(df['price'])
df['area_log'] = np.log1p(df['area'])

# %%
sns.histplot(df['price'], kde=True)
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(df['price_log'], kde=True)
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# if vif>10 then it is problem we should remove that column

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

X = df[['area', 'bedrooms', 'bathrooms', 'stories', 'parking']]
vif = pd.DataFrame()
vif["Feature"] = X.columns
vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif
# Out:
#      Feature       VIF
# 0       area  1.188515
# 1   bedrooms  1.315080
# 2  bathrooms  1.253347
# 3    stories  1.255929
# 4    parking  1.179551

# %%
df.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus_furnished',
#        'furnishingstatus_semi-furnished', 'furnishingstatus_unfurnished',
#        'pricepersqfeet', 'total_rooms', 'area_bathrooms', 'price_log',
#        'area_log'],
#       dtype='object')

# %%
X = df.drop(['price_log','price','area_log'],axis = 1)
y = df['price']
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 42,random_state = 42)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 42,random_state = 42)

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score 
mse = mean_squared_error(y_pred,y_test)
mae = mean_absolute_error(y_pred,y_test) 
r2 = r2_score(y_pred,y_test) 
rmse = np.sqrt(mse)
print(f"R² Score: {r2:.4f}")
print(f"RMSE: {rmse:.4f}")
print(f"MAE: {mae:.4f}")
# Out:
# R² Score: 0.5167
# RMSE: 0.5715
# MAE: 0.4560
